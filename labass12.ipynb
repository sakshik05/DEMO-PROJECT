# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshik05/DEMO-PROJECT/blob/main/labass12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Diamonds DataFrame Solution
import pandas as pd

# Create DataFrame
data = {
    'carat': [0.23, 0.21, 0.23, 0.29, 0.31],
    'cut': ['Ideal', 'Premium', 'Good', 'Premium', 'Good'],
    'color': ['E', 'E', 'E', 'I', 'J'],
    'clarity': ['SI2', 'SI1', 'VS1', 'VS2', 'SI2'],
    'depth': [61.5, 59.8, 56.9, 62.4, 63.3],
    'table': [55.0, 61.0, 65.0, 58.0, 58.0],
    'price': [326, 326, 327, 334, 335],
    'x': [3.95, 3.89, 4.05, 4.20, 4.34],
    'y': [3.98, 3.84, 4.07, 4.23, 4.35],
    'z': [2.43, 2.31, 2.31, 2.63, 2.75]
}

df = pd.DataFrame(data)

print("DataFrame:\n", df)

# i) Mean price for each cut
print("\nMean price for each cut:")
print(df.groupby('cut')['price'].mean())

# ii) Count, minimum and maximum price for each cut
print("\nCount, Min and Max price for each cut:")
print(df.groupby('cut')['price'].agg(['count', 'min', 'max']))

# iii) Average of x, y, z separately
print("\nAverage values:")
print("x average:", df['x'].mean())
print("y average:", df['y'].mean())
print("z average:", df['z'].mean())
# Out:
# DataFrame:
#     carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
# Mean price for each cut:
# cut
# Good       331.0
# Ideal      326.0
# Premium    330.0
# Name: price, dtype: float64
#
# Count, Min and Max price for each cut:
#          count  min  max
# cut
# Good         2  327  335
# Ideal        1  326  326
# Premium      2  326  334
#
# Average values:
# x average: 4.086
# y average: 4.093999999999999
# z average: 2.4859999999999998

# %%
import pandas as pd
import os

# --- STEP 1: CREATE SAMPLE DATA (Only for testing if you haven't uploaded your file) ---
file_name = "employee.xlsx"

if not os.path.exists(file_name):
    data = {
        'Employee ID': [101, 102, 103, 104, 105],
        'Employee Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Department': ['Automotive', 'Banking', 'Automotive', 'Retail', 'Infrastructure'],
        'Designation': ['Developer', 'Manager', 'Developer', 'Analyst', 'Developer']
    }
    sample_df = pd.DataFrame(data)
    sample_df.to_excel(file_name, index=False)
    print(f"✅ Created a sample '{file_name}' for testing.")

# --- STEP 2: READ THE FILE ---
try:
    # We use engine='openpyxl' to ensure Excel compatibility
    df = pd.read_excel(file_name)
    print("✅ File loaded successfully!\n")
except Exception as e:
    print(f"❌ Error: Could not find '{file_name}'. Please upload it to the Colab sidebar.")
    raise # Stops execution if file is missing

# --- STEP 3: ASSIGNMENT REPORTS ---

# a) Print the list of employees working for "Automotive" domain
print("--- Report (a): Automotive Domain Employees ---")
automotive_list = df[df['Department'] == 'Automotive']
display(automotive_list)

# b) Print the details of an employee with employee ID given by an end user
print("\n--- Report (b): Employee Search ---")
try:
    search_id = int(input("Enter Employee ID to search: "))
    result = df[df['Employee ID'] == search_id]

    if not result.empty:
        display(result)
    else:
        print(f"No employee found with ID {search_id}")
except ValueError:
    print("Invalid input! Please enter a numeric ID.")

# d) Print the list of all the Developers of Infosys
print("\n--- Report (d): List of Developers ---")
developers_list = df[df['Designation'] == 'Developer']
display(developers_list)
# Out:
# ✅ Created a sample 'employee.xlsx' for testing.
# ✅ File loaded successfully!
#
# --- Report (a): Automotive Domain Employees ---
#    Employee ID Employee Name  Department Designation
# 0          101         Alice  Automotive   Developer
# 2          103       Charlie  Automotive   Developer
# --- Report (b): Employee Search ---
